# %% [markdown]
# -- p. 37
#
# We're doing some exploratory data analysis (EDA) on some simulated adds for the NYT.

# %%
# %matplotlib inline

# %%
from __future__ import division

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# It's nice to have a peak at the data format before progressing.
# This one is a standard, already cleaned csv.
#
# We'lre told that the gender column is coded 0 for female, 1 for male.

# %%
# !head -n 5 dds_datasets/nyt1.csv
# Out:
# "Age","Gender","Impressions","Clicks","Signed_In"
# 36,0,3,0,1
# 73,1,3,0,1
# 30,0,3,0,1
# 49,1,3,0,1

# %%
df = pd.read_csv("dds_datasets/nyt1.csv")
df.head()
# Out:
#    Age  Gender  Impressions  Clicks  Signed_In
# 0   36       0            3       0          1
# 1   73       1            3       0          1
# 2   30       0            3       0          1
# 3   49       1            3       0          1
# 4   47       1           11       0          1
#
# [5 rows x 5 columns]

# %% [markdown]
# The first prompt is to create an `age_group` column that bins the ages according to `"<18", "18-24", "25-34", "35-44", "45-54", "55-64", and "65+".`
#
# We'll use the pandas `cut` function:

# %% [markdown]
# ```python
# pd.cut?
# Type:       function
# String Form:<function cut at 0x10961df50>
# File:       /Users/admin/Envs/pandas-dev/lib/python2.7/site-packages/pandas-0.13.1_106_g8fbe54a-py2.7-macosx-10.9-x86_64.egg/pandas/tools/tile.py
# Definition: pd.cut(x, bins, right=True, labels=None, retbins=False, precision=3, include_lowest=False)
# Docstring:
# Return indices of half-open bins to which each value of `x` belongs.
# ```

# %%
bins = [-np.inf, 0, 17, 24, 34, 44, 54, 64, np.inf]

df['age_bin'] = pd.cut(df.Age, bins)
df.head()
# Out:
#    Age  Gender  Impressions  Clicks  Signed_In  ctr    age_bin
# 0   36       0            3       0          1    0   (34, 44]
# 1   73       1            3       0          1    0  (64, inf]
# 2   30       0            3       0          1    0   (24, 34]
# 3   49       1            3       0          1    0   (44, 54]
# 4   47       1           11       0          1    0   (44, 54]
#
# [5 rows x 7 columns]

# %% [markdown]
# We can now [`grouby`](http://pandas.pydata.org/pandas-docs/stable/groupby.html) the `age_bin` and give some summary statistics.

# %%
df.groupby(df.age_bin)['Age'].agg([len, np.min, np.max, np.mean])
# Out:
#               len  amin  amax       mean
# age_bin
# (-inf, 0]  137106     0     0   0.000000
# (0, 17]     13828     7    17  15.262149
# (17, 24]    40694    18    24  20.833317
# (24, 34]    58174    25    34  29.503352
# (34, 44]    70860    35    44  39.494680
# (44, 54]    64288    45    54  49.492580
# (54, 64]    44738    55    64  59.498189
# (64, inf]   28753    65   108  72.988697
#
# [8 rows x 4 columns]

# %% [markdown]
# A lot of those ages don't look valid, we have 137106 at age 0:

# %%
pd.value_counts(df.Age).head()
# Out:
# 0     137106
# 37      7983
# 36      7933
# 42      7919
# 41      7906
# dtype: int64

# %% [markdown]
# We probably don't have the age or gender information on users who are not signed in:

# %%
df.groupby("Signed_In").mean()
# Out:
#                  Age    Gender  Impressions   Clicks       ctr
# Signed_In
# 0           0.000000  0.000000     4.999657  0.14208  0.028355
# 1          42.062054  0.523644     5.010584  0.07148  0.014254
#
# [2 rows x 5 columns]

# %% [markdown]
# Yep, that looks like it. So if someone isn't signed in they're given an Age of 0 and a Gender of female. Those *should* be `NaNs`, but as it is we'll be careful about our analysis and filter to only signed in users when reporting Age or Gender statsitics.

# %%
df.groupby("age_bin").mean()
# Out:
#                  Age    Gender  Impressions    Clicks  Signed_In       ctr
# age_bin
# (-inf, 0]   0.000000  0.000000     4.999657  0.142080          0  0.028355
# (0, 17]    15.262149  0.684842     5.007159  0.149335          1  0.030277
# (17, 24]   20.833317  0.533764     5.002826  0.053251          1  0.010734
# (24, 34]   29.503352  0.532162     4.993829  0.050486          1  0.010146
# (34, 44]   39.494680  0.531696     5.021507  0.051679          1  0.010286
# (44, 54]   49.492580  0.528979     5.010406  0.050274          1  0.009958
# (54, 64]   59.498189  0.536188     5.022308  0.101837          1  0.020307
# (64, inf]  72.988697  0.363266     5.012347  0.151289          1  0.029803
#
# [8 rows x 6 columns]

# %% [markdown]
# We can visualize the distribution of Impressions, grouped by age bin.

# %%
r = df.groupby('age_bin')['Impressions'].hist(alpha=.75)
r.iloc[0].set_xlabel("Impressions")

# %% [markdown]
# Sadly we don't have any labels about which bin comes from where. There's an [open issue](https://github.com/pydata/pandas/issues/6279) about this. The pandas groupby code is intimidating, so I haven't gotten around to fix it yet.
#
# We can also visualize with a boxplot, which shows there isn't a lot of variation in impressions across age bins.

# %%
ax = df.boxplot("Impressions", by='age_bin')

# %% [markdown]
# That gets close to the R sample code. I'm not sure what the dots above the whiskers are in the R version.

# %% [markdown]
# Next we want to "Define a new variable to segment or categorize users based on their click behavior.". This is a bit vague, so let's take a look at the distribution of clicks before doing any binning.

# %%
pd.value_counts(df.Clicks).sort_index(ascending=False).plot(kind='barh')

# %% [markdown]
# Now we want to calculate the Click Through Rate (CTR) = $ \frac{|Clicks|}{|Impressions|} $.
#
# We'll need to filter out the users with zero impressions so we aren't dividing by 0 anywhere. `NaN`s are created in those locations for `ctr`.

# %%
# calculate click through rate (CTR)
idx = df[df.Impressions > 0].index
df['ctr'] = df.loc[idx, 'Clicks'] / df.loc[idx, 'Impressions']

# %%
df.groupby(df.Impressions > 0)['Clicks'].describe().unstack()
# Out:
#               count      mean       std  min  25%  50%  75%  max
# Impressions
# False          3066  0.000000  0.000000    0    0    0    0    0
# True         455375  0.093218  0.310922    0    0    0    0    4
#
# [2 rows x 8 columns]

# %%
# Some Density plots:

axes = df[df.Impressions > 0].groupby('age_bin')['ctr'].plot(kind='kde')
# Out:
# age_bin
# (-inf, 0]    Axes(0.125,0.125;0.775x0.775)
# (0, 17]      Axes(0.125,0.125;0.775x0.775)
# (17, 24]     Axes(0.125,0.125;0.775x0.775)
# (24, 34]     Axes(0.125,0.125;0.775x0.775)
# (34, 44]     Axes(0.125,0.125;0.775x0.775)
# (44, 54]     Axes(0.125,0.125;0.775x0.775)
# (54, 64]     Axes(0.125,0.125;0.775x0.775)
# (64, inf]    Axes(0.125,0.125;0.775x0.775)
# dtype: object

# %% [markdown]
# That density plot isn't all that helpful since so much of the mass is concentrated at 0. Let's filter those out.

# %%
# again we have the label bug. Someone should fix that.
axes = df[df.Clicks > 0].groupby('age_bin')['ctr'].plot(kind='kde')
axes.iloc[0].set_xlabel("Click Through Rate")

# %%
# Distributions impression and CTR
def plot_distributions(df):
    
    fig, (ax1, ax2) = plt.subplots(ncols=2)
    
    ax1 = df.Impressions.hist(bins=20, color='k', ax=ax1)
    ax1.set_title("Impressions")
    
    ax2 = df.ctr.hist(bins=20, ax=ax2, log=True)
    ax2.set_title("Log Click-Through-Rate")
    return ax1, ax2

# %%
plot_distributions(df)
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x10b042dd0>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x10b06e650>)

# %% [markdown]
# So that's it for a single day. At this point, we want to generalize what we've done to other days.
#
# This is a pretty common pattern in EDA. Take a (hopefully representative) subsample of your data, explore it all the way through, and then refactor your code to handle new samples. Of course, you'll think of new things to do along the way, so it's not ever that straightforward.
#
# The API we'll implement will take a filename as an input. The output will be a set of graphs and tables. For now we'll just display them in the notebook, but you'd probably want to save them to disk.

# %%
def explore(infile):
    """
    Perform some EDA on a nyt add file.
    
    Parameters
    ----------    
    infile: str
        path to a csv with (simulated) NYT add tracking
        
    Returns
    -------
    None

    """
    df = pd.read_csv(infile)
    bins = [-np.inf, 0, 17, 24, 34, 44, 54, 64, np.inf]
    df['age_bin'] = pd.cut(df.Age, bins)
    # for identifying plots
    df.name = infile.split('/')[-1].split('.')[0]
    
    print(describe_age_by_age_bin(df))
    print(means_by_signed_in(df))
    print(means_by_bin(df))
    
    plot_impressions_by_age(df)
    plot_impressions_boxplot(df)
    
    # CTR
    idx = df[df.Impressions > 0].index
    df['ctr'] = df.loc[idx, 'Clicks'] / df.loc[idx, 'Impressions']
    
    print(describe_clicks_by_impressions(df))
    plot_ctr_by_age(df, only_positive=True)
    plot_distributions(df)
    
def describe_age_by_age_bin(df):
    return df.groupby(df.age_bin)['Age'].agg([len, np.min, np.max, np.mean])

def means_by_signed_in(df):
    return df.groupby("Signed_In").mean()

def means_by_bin(df):
    return df.groupby("age_bin").mean()

def plot_impressions_by_age(df):
    r = df.groupby('age_bin')['Impressions'].hist(alpha=.75)
    r.iloc[0].set_xlabel("Impressions")
    r.iloc[0].set_title(df.name)
    plt.draw()
    plt.show()

def plot_impressions_boxplot(df):
    ax = df.boxplot("Impressions", by='age_bin')
    ax.set_title("Impressions for " + df.name)

def describe_clicks_by_impressions(df):
    return df.groupby(df.Impressions > 0)['Clicks'].describe().unstack()

def plot_ctr_by_age(df, only_positive=False):
    if only_positive:
        # again we have the label bug. Someone should fix that.
        axes = df[df.Clicks > 0].groupby('age_bin')['ctr'].plot(kind='kde')
    else:
        axes = df[df.Impressions > 0].groupby('age_bin')['ctr'].plot(kind='kde')
    axes.iloc[0].set_xlabel("Click Through Rate")
    axes.iloc[0].set_title(df.name)
    plt.draw()
    plt.show()

def plot_distributions(df):
    
    fig, (ax1, ax2) = plt.subplots(ncols=2)
    
    ax1 = df.Impressions.hist(bins=20, color='k', ax=ax1)
    ax1.set_title("Impressions for " + df.name)
    
    ax2 = df.ctr.hist(bins=20, ax=ax2, log=True)
    ax2.set_title("Log Click-Through-Rate for " + df.name)
    return ax1, ax2

# %%
explore('dds_datasets/nyt1.csv')
# Out:
#               len  amin  amax       mean
# age_bin
# (-inf, 0]  137106     0     0   0.000000
# (0, 17]     13828     7    17  15.262149
# (17, 24]    40694    18    24  20.833317
# (24, 34]    58174    25    34  29.503352
# (34, 44]    70860    35    44  39.494680
# (44, 54]    64288    45    54  49.492580
# (54, 64]    44738    55    64  59.498189
# (64, inf]   28753    65   108  72.988697
#
# [8 rows x 4 columns]
#                  Age    Gender  Impressions   Clicks
# Signed_In
# 0           0.000000  0.000000     4.999657  0.14208
# 1          42.062054  0.523644     5.010584  0.07148
#
# [2 rows x 4 columns]
#                  Age    Gender  Impressions    Clicks  Signed_In
# age_bin
# (-inf, 0]   0.000000  0.000000     4.999657  0.142080          0
# (0, 17]    15.262149  0.684842     5.007159  0.149335          1
# (17, 24]   20.833317  0.533764     5.002826  0.053251          1
# (24, 34]   29.503352  0.532162     4.993829  0.050486          1
# (34, 44]   39.494680  0.531696     5.021507  0.051679          1
# (44, 54]   49.492580  0.528979     5.010406  0.050274          1
# (54, 64]   59.498189  0.536188     5.022308  0.101837          1
# (64, inf]  72.988697  0.363266     5.012347  0.151289          1
#
# [8 rows x 5 columns]
#               count      mean       std  min  25%  50%  75%  max
# Impressions
# False          3066  0.000000  0.000000    0    0    0    0    0
# True         455375  0.093218  0.310922    0    0    0    0    4
#
# [2 rows x 8 columns]

# %% [markdown]
# Pretty cool. We should probably do some more labeling, but that works for now. Let's iterate over a few files:

# %%
files = ['dds_datasets/nyt2.csv', 'dds_datasets/nyt3.csv', 'dds_datasets/nyt4.csv', 'dds_datasets/nyt5.csv']

for f in files:
    explore(f)
# Out:
#               len  amin  amax       mean
# age_bin
# (-inf, 0]  134572     0     0   0.000000
# (0, 17]     13855     4    17  15.263659
# (17, 24]    39809    18    24  20.845914
# (24, 34]    56898    25    34  29.500738
# (34, 44]    68974    35    44  39.512961
# (44, 54]    63307    45    54  49.506168
# (54, 64]    44043    55    64  59.497514
# (64, inf]   28477    65   111  72.941040
#
# [8 rows x 4 columns]
#                  Age    Gender  Impressions   Clicks
# Signed_In
# 0           0.000000  0.000000     5.002772  0.14214
# 1          42.100408  0.534165     4.998218  0.07174
#
# [2 rows x 4 columns]
#                  Age    Gender  Impressions    Clicks  Signed_In
# age_bin
# (-inf, 0]   0.000000  0.000000     5.002772  0.142140          0
# (0, 17]    15.263659  0.694912     5.000000  0.151931          1
# (17, 24]   20.845914  0.540782     4.987189  0.056645          1
# (24, 34]   29.500738  0.541073     5.007083  0.050230          1
# (34, 44]   39.512961  0.545278     4.987068  0.051019          1
# (44, 54]   49.506168  0.543257     4.994392  0.051227          1
# (54, 64]   59.497514  0.543469     5.020435  0.101605          1
# (64, inf]  72.941040  0.371387     4.996207  0.146399          1
#
# [8 rows x 5 columns]
#               count     mean       std  min  25%  50%  75%  max
# Impressions
# False          3056  0.00000  0.000000    0    0    0    0    0
# True         446879  0.09343  0.311441    0    0    0    0    5
#
# [2 rows x 8 columns]
#               len  amin  amax       mean
# age_bin
# (-inf, 0]  132083     0     0   0.000000
# (0, 17]     13501     5    17  15.243612
# (17, 24]    38854    18    24  20.848870
# (24, 34]    55937    25    34  29.510056
# (34, 44]    67199    35    44  39.506689
# (44, 54]    61759    45    54  49.488382
# (54, 64]    43306    55    64  59.478363
# (64, inf]   27731    65   109  72.962785
#
# [8 rows x 4 columns]
#                  Age    Gender  Impressions    Clicks
# Signed_In
# 0           0.000000  0.000000     4.995155  0.141411
# 1          42.093355  0.524002     4.996850  0.071206
#
# [2 rows x 4 columns]
#                  Age    Gender  Impressions    Clicks  Signed_In
# age_bin
# (-inf, 0]   0.000000  0.000000     4.995155  0.141411          0
# (0, 17]    15.243612  0.692023     4.997630  0.150359          1
# (17, 24]   20.848870  0.534462     4.997452  0.056133          1
# (24, 34]   29.510056  0.530597     4.996425  0.049663          1
# (34, 44]   39.506689  0.531317     5.008378  0.050715          1
# (44, 54]   49.488382  0.529720     4.984925  0.048965          1
# (54, 64]   59.478363  0.535030     5.002101  0.099940          1
# (64, inf]  72.962785  0.366557     4.986910  0.151563          1
#
# [8 rows x 5 columns]
#               count      mean       std  min  25%  50%  75%  max
# Impressions
# False          2999  0.000000  0.000000    0    0    0    0    0
# True         437371  0.092896  0.310628    0    0    0    0    6
#
# [2 rows x 8 columns]
#               len  amin  amax       mean
# age_bin
# (-inf, 0]  133233     0     0   0.000000
# (0, 17]     13332     7    17  15.253300
# (17, 24]    39520    18    24  20.833451
# (24, 34]    55610    25    34  29.493221
# (34, 44]    67936    35    44  39.490211
# (44, 54]    61721    45    54  49.504917
# (54, 64]    43741    55    64  59.506138
# (64, inf]   27764    65   108  72.978785
#
# [8 rows x 4 columns]
#                  Age   Gender  Impressions    Clicks
# Signed_In
# 0           0.000000  0.00000     5.011071  0.141572
# 1          42.096717  0.52848     5.000291  0.071467
#
# [2 rows x 4 columns]
#                  Age    Gender  Impressions    Clicks  Signed_In
# age_bin
# (-inf, 0]   0.000000  0.000000     5.011071  0.141572          0
# (0, 17]    15.253300  0.690894     5.009376  0.149340          1
# (17, 24]   20.833451  0.534286     5.001544  0.054681          1
# (24, 34]   29.493221  0.541575     4.994947  0.050135          1
# (34, 44]   39.490211  0.536755     4.997100  0.050827          1
# (44, 54]   49.504917  0.536398     4.987168  0.051295          1
# (54, 64]   59.506138  0.534441     5.007956  0.100752          1
# (64, inf]  72.978785  0.368751     5.029751  0.149906          1
#
# [8 rows x 5 columns]
#               count      mean       std  min  25%  50%  75%  max
# Impressions
# False          2948  0.000000  0.000000    0    0    0    0    0
# True         439909  0.093178  0.310774    0    0    0    0    4
#
# [2 rows x 8 columns]
#               len  amin  amax       mean
# age_bin
# (-inf, 0]  111351     0     0   0.000000
# (0, 17]     11204     4    17  15.243038
# (17, 24]    32828    18    24  20.856434
# (24, 34]    46980    25    34  29.510026
# (34, 44]    56598    35    44  39.513640
# (44, 54]    51929    45    54  49.477344
# (54, 64]    36054    55    64  59.494009
# (64, inf]   23384    65   106  73.017662
#
# [8 rows x 4 columns]
#                  Age    Gender  Impressions    Clicks
# Signed_In
# 0           0.000000  0.000000     4.995195  0.141992
# 1          42.088614  0.526618     5.000220  0.070740
#
# [2 rows x 4 columns]
#                  Age    Gender  Impressions    Clicks  Signed_In
# age_bin
# (-inf, 0]   0.000000  0.000000     4.995195  0.141992          0
# (0, 17]    15.243038  0.688415     5.012317  0.148429          1
# (17, 24]   20.856434  0.535945     5.011332  0.056111          1
# (24, 34]   29.510026  0.539080     5.002788  0.049553          1
# (34, 44]   39.513640  0.534772     4.988480  0.049613          1
# (44, 54]   49.477344  0.532958     5.012228  0.050261          1
# (54, 64]   59.494009  0.536168     4.993094  0.097049          1
# (64, inf]  73.017662  0.362427     4.986401  0.152668          1
#
# [8 rows x 5 columns]
#               count      mean       std  min  25%  50%  75%  max
# Impressions
# False          2505  0.000000  0.000000    0    0    0    0    0
# True         367823  0.092792  0.310474    0    0    0    0    5
#
# [2 rows x 8 columns]

# %% [markdown]
# It would be interesting to compare the evolution of these metrics over time. We could use a pandas `Panel` to store the series of `DataFrames`, one for each date. But that will have to wait for a future post.
