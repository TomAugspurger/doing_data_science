# %% [markdown]
# p. 85
#
# Using the cleaned NYC Manhatten data set from chapter 2.

# %%
# %load_ext autoreload
# %autoreload

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
import seaborn as sns

# %%
df = pd.read_excel("dds_datasets/rollingsales_manhattan.xls", 0, skiprows=4)
df = df.rename(columns=lambda x: x.replace('\n', '').replace('-', '_').replace(' ', '_').lower())
df['neighborhood'] = df.neighborhood.str.strip()
df['building_class_category'] = df.building_class_category.str.strip()

neighborhood, neighborhood_keys = pd.factorize(df.neighborhood)
df['neighborhood_f'] = neighborhood

building_f, building_keys = pd.factorize(df.building_class_category)
df['building_f'] = building_f

df[['saleprice_ln',
    'gross_square_feet_ln',
    'land_square_feet_ln']] = np.log(df[['saleprice', 'gross_square_feet',
                                         'land_square_feet']])

# %%
pure = df.query("saleprice > 0 & gross_square_feet > 0 & land_square_feet > 0")

# %%
pure[['saleprice', 'gross_square_feet', 'land_square_feet']].describe()
# Out:
#           saleprice  gross_square_feet  land_square_feet
# count  2.759000e+03        2759.000000       2759.000000
# mean   8.204364e+06       65744.841247       6262.634650
# std    3.841248e+07       71047.538927       7937.895426
# min    1.000000e+00         999.000000        469.000000
# 25%    5.790000e+04        7171.000000       2320.000000
# 50%    7.500000e+05       52290.000000       7532.000000
# 75%    5.166704e+06      112850.000000       7532.000000
# max    1.100000e+09      940000.000000     213650.000000
#
# [8 rows x 3 columns]

# %%
mod = sm.OLS.from_formula("saleprice_ln ~ gross_square_feet_ln", pure)
res = mod.fit()
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           saleprice_ln   R-squared:                       0.202
# Model:                            OLS   Adj. R-squared:                  0.201
# Method:                 Least Squares   F-statistic:                     696.1
# Date:                Fri, 28 Feb 2014   Prob (F-statistic):          5.61e-137
# Time:                        08:12:30   Log-Likelihood:                -6449.9
# No. Observations:                2759   AIC:                         1.290e+04
# Df Residuals:                    2757   BIC:                         1.292e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ----------------------------------------------------------------------------------------
# Intercept               21.9877      0.335     65.548      0.000        21.330    22.645
# gross_square_feet_ln    -0.8506      0.032    -26.384      0.000        -0.914    -0.787
# ==============================================================================
# Omnibus:                      784.329   Durbin-Watson:                   1.053
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             8668.842
# Skew:                          -1.022   Prob(JB):                         0.00
# Kurtosis:                      11.440   Cond. No.                         73.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# not random noise in the residuals
# what is that large cluster around 11.75 gsqrf_ln and 12 saleprice?

sns.regplot('gross_square_feet_ln', 'saleprice_ln', pure)

# %%
fig, ax = plt.subplots()
ax.scatter(res.fittedvalues, res.resid, color='k', alpha=.7)

# %%
mod2 = sm.OLS.from_formula("saleprice_ln ~ land_square_feet_ln + gross_square_feet_ln +"
                           "neighborhood_f", pure)
res2 = mod2.fit()
res2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           saleprice_ln   R-squared:                       0.279
# Model:                            OLS   Adj. R-squared:                  0.278
# Method:                 Least Squares   F-statistic:                     355.0
# Date:                Fri, 28 Feb 2014   Prob (F-statistic):          6.32e-195
# Time:                        08:15:54   Log-Likelihood:                -6309.5
# No. Observations:                2759   AIC:                         1.263e+04
# Df Residuals:                    2755   BIC:                         1.265e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ----------------------------------------------------------------------------------------
# Intercept               13.7264      0.583     23.543      0.000        12.583    14.870
# land_square_feet_ln      2.2248      0.131     17.040      0.000         1.969     2.481
# gross_square_feet_ln    -1.8571      0.068    -27.194      0.000        -1.991    -1.723
# neighborhood_f          -0.0067      0.005     -1.279      0.201        -0.017     0.004
# ==============================================================================
# Omnibus:                     1245.512   Durbin-Watson:                   1.121
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            17177.693
# Skew:                          -1.769   Prob(JB):                         0.00
# Kurtosis:                      14.701   Cond. No.                         363.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(16, 8))
ax1.scatter(res.fittedvalues, res.resid, color='k', alpha=.7)
ax1.set_title("Model 1")
ax2.scatter(res2.fittedvalues, res2.resid, color='k', alpha=.7)
ax2.set_title("Model 2")
ax2.set_xlim(ax1.get_xlim())
# Out:
# (9.0, 17.0)

# %%
mod3 = sm.OLS.from_formula("saleprice_ln ~ land_square_feet_ln + gross_square_feet_ln +"
                           "neighborhood_f + building_f", pure)
res3 = mod3.fit()
res3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           saleprice_ln   R-squared:                       0.340
# Model:                            OLS   Adj. R-squared:                  0.339
# Method:                 Least Squares   F-statistic:                     354.7
# Date:                Fri, 28 Feb 2014   Prob (F-statistic):          1.56e-246
# Time:                        08:27:52   Log-Likelihood:                -6187.3
# No. Observations:                2759   AIC:                         1.238e+04
# Df Residuals:                    2754   BIC:                         1.241e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ----------------------------------------------------------------------------------------
# Intercept               13.4515      0.558     24.101      0.000        12.357    14.546
# land_square_feet_ln      1.4478      0.134     10.799      0.000         1.185     1.711
# gross_square_feet_ln    -1.0255      0.084    -12.275      0.000        -1.189    -0.862
# neighborhood_f          -0.0032      0.005     -0.646      0.518        -0.013     0.007
# building_f              -0.1000      0.006    -15.976      0.000        -0.112    -0.088
# ==============================================================================
# Omnibus:                     1536.994   Durbin-Watson:                   1.121
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            26921.706
# Skew:                          -2.259   Prob(JB):                         0.00
# Kurtosis:                      17.621   Cond. No.                         441.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
fig, ax = plt.subplots()
ax.scatter(res3.fittedvalues, res3.resid, color='k', alpha=.7)

# %%
ax = sns.distplot(res2.resid)
ax.set_title("Model 2 Residuals")

# %%
# interact neighborhood and building category
mod4 = sm.OLS.from_formula("saleprice_ln ~ gross_square_feet_ln + land_square_feet_ln + "
                           "neighborhood_f * building_f", pure)
res4 = mod4.fit()
res4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           saleprice_ln   R-squared:                       0.367
# Model:                            OLS   Adj. R-squared:                  0.366
# Method:                 Least Squares   F-statistic:                     319.8
# Date:                Fri, 28 Feb 2014   Prob (F-statistic):          1.44e-270
# Time:                        08:30:39   Log-Likelihood:                -6128.7
# No. Observations:                2759   AIC:                         1.227e+04
# Df Residuals:                    2753   BIC:                         1.230e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------------------
# Intercept                    12.3393      0.556     22.197      0.000        11.249    13.429
# gross_square_feet_ln         -0.8468      0.083    -10.152      0.000        -1.010    -0.683
# land_square_feet_ln           1.1722      0.134      8.769      0.000         0.910     1.434
# neighborhood_f                0.0706      0.008      8.448      0.000         0.054     0.087
# building_f                    0.0663      0.016      4.041      0.000         0.034     0.098
# neighborhood_f:building_f    -0.0071      0.001    -10.929      0.000        -0.008    -0.006
# ==============================================================================
# Omnibus:                     1639.506   Durbin-Watson:                   1.160
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            30873.711
# Skew:                          -2.447   Prob(JB):                         0.00
# Kurtosis:                      18.640   Cond. No.                     7.05e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.05e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
ax = sns.distplot(res4.resid)
ax.set_title("Model 4 Residuals")

sns.regplot(res4.fittedvalues, res4.resid)

# %%
sns.distplot(pure.saleprice_ln)

# %%
# let's punt a bit on the reason, and just make a dummy for < 13
pure['saleprice_lt_d'] = pure.saleprice_ln < 13

# %%
mod5 = sm.OLS.from_formula("saleprice_ln ~ land_square_feet_ln + gross_square_feet_ln +"
                           "neighborhood_f + building_f + saleprice_lt_d", pure)
res5 = mod5.fit()
res5.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           saleprice_ln   R-squared:                       0.789
# Model:                            OLS   Adj. R-squared:                  0.789
# Method:                 Least Squares   F-statistic:                     2063.
# Date:                Fri, 28 Feb 2014   Prob (F-statistic):               0.00
# Time:                        08:33:43   Log-Likelihood:                -4611.7
# No. Observations:                2759   AIC:                             9235.
# Df Residuals:                    2753   BIC:                             9271.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------------------
# Intercept                  9.9632      0.319     31.269      0.000         9.338    10.588
# saleprice_lt_d[T.True]    -7.1163      0.093    -76.637      0.000        -7.298    -6.934
# land_square_feet_ln       -0.3758      0.079     -4.733      0.000        -0.531    -0.220
# gross_square_feet_ln       0.8525      0.053     16.029      0.000         0.748     0.957
# neighborhood_f             0.0078      0.003      2.750      0.006         0.002     0.013
# building_f                 0.0483      0.004     11.989      0.000         0.040     0.056
# ==============================================================================
# Omnibus:                     1633.383   Durbin-Watson:                   1.604
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            43055.118
# Skew:                          -2.314   Prob(JB):                         0.00
# Kurtosis:                      21.791   Cond. No.                         444.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
sns.distplot(res5.resid)
sns.regplot(res5.fittedvalues, res5.resid)

# %% [markdown]
# That boosted the $R^2$ a lot. It really does seem like there are two samples here.
#
# Let's figure out what's going on. What does that dummy variable correlate with?

# %% [markdown]
# ## With K-NN from scikit-learn

# %%
y = df.dropna().saleprice_ln.values

# %%
y.shape
# Out:
# (2759,)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27395 entries, 0 to 27394
# Data columns (total 27 columns):
# Unnamed: 0                        27395 non-null int64
# borough                           27395 non-null int64
# neighborhood                      27395 non-null object
# building_class_category           27395 non-null object
# tax_class_at_present              27395 non-null object
# block                             27395 non-null int64
# lot                               27395 non-null int64
# ease_ment                         27395 non-null object
# building_class_at_present         27395 non-null object
# address                           27395 non-null object
# apartmentnumber                   27395 non-null object
# zip_code                          27395 non-null int64
# residential_units                 27395 non-null int64
# commercial_units                  27395 non-null int64
# total_units                       27395 non-null int64
# land_square_feet                  4489 non-null float64
# gross_square_feet                 4326 non-null float64
# year_built                        20954 non-null float64
# tax_class_at_time_of_sale         27395 non-null int64
# building_class_at_time_of_sale    27395 non-null object
# saleprice                         19802 non-null float64
# sale_date                         27395 non-null object
# neighborhood_f                    27395 non-null int64
# saleprice_ln                      19802 non-null float64
# gross_square_feet_ln              4326 non-null float64
# land_square_feet_ln               4489 non-null float64
# building_class_category_f         27395 non-null int64
# dtypes: float64(7), int64(11), object(9)
